# %% [markdown]
# 整理matplotlib画图时常用设置命令。

# %%
import numpy as np
import matplotlib.pyplot as plt

x = np.linspace(0, np.pi, 30)
y = np.sin(x)
a = np.random.normal(10, 2, 1000)  #按照高斯分布采样 期望值，标准差，size

fig = plt.figure(figsize=(12, 12))
ax1 = fig.add_subplot(3, 1, 1)
ax2 = fig.add_subplot(3, 3, 4)
ax3 = fig.add_subplot(3, 3, 5)
ax4 = fig.add_subplot(3, 3, 6)

ax1.scatter(x, y)

ax2.plot(x**x, y)

ax3.imshow(np.sin(x) + y.reshape(-1,1))

ax4.hist(a,40)
# Out:
# (array([ 1.,  0.,  2.,  3.,  0.,  3.,  9., 11., 10., 18., 18., 26., 41.,
#         28., 52., 63., 58., 51., 64., 67., 65., 62., 56., 45., 51., 47.,
#         48., 22., 22., 15., 17.,  8.,  5.,  4.,  2.,  2.,  3.,  0.,  0.,
#          1.]),
#  array([ 3.89722588,  4.20690185,  4.51657782,  4.82625378,  5.13592975,
#          5.44560572,  5.75528169,  6.06495766,  6.37463362,  6.68430959,
#          6.99398556,  7.30366153,  7.6133375 ,  7.92301346,  8.23268943,
#          8.5423654 ,  8.85204137,  9.16171734,  9.47139331,  9.78106927,
#         10.09074524, 10.40042121, 10.71009718, 11.01977315, 11.32944911,
#         11.63912508, 11.94880105, 12.25847702, 12.56815299, 12.87782895,
#         13.18750492, 13.49718089, 13.80685686, 14.11653283, 14.42620879,
#         14.73588476, 15.04556073, 15.3552367 , 15.66491267, 15.97458863,
#         16.2842646 ]),
#  <a list of 40 Patch objects>)
